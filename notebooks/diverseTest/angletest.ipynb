# %%
import sys
sys.path.append('/home/lucyliuu/stim_behavior/')
from scripts.rhesus_macaque.dataLoader import DataLoader, FatigueAnalysis, plotDecay, plotDecaySingle
# %load_ext autoreload
# %autoreload 2

# %%
import deeplabcut
deeplabcut.extract_outlier_frames?
# Out:
# Loading DLC 3.0.0rc4...
# Signature:
# deeplabcut.extract_outlier_frames(
#     config,
#     videos,
#     videotype='',
#     shuffle=1,
#     trainingsetindex=0,
#     outlieralgorithm='jump',
#     frames2use=None,
#     comparisonbodyparts='all',
#     epsilon=20,
#     p_bound=0.01,
#     ARdegree=3,
#     MAdegree=1,
#     alpha=0.01,
#     extractionalgorithm='kmeans',
#     automatic=False,
#     cluster_resizewidth=30,
#     cluster_color=False,
#     opencv=True,
#     savelabeled=False,
#     copy_videos=False,
#     destfolder=None,
#     modelprefix='',
#     track_method='',
# )
# Docstring:
# Extracts the outlier frames.
#
# Extracts the outlier frames if the predictions are not correct for a certain video
# from the cropped video running from start to stop as defined in config.yaml.
#
# Another crucial parameter in config.yaml is how many frames to extract
# ``numframes2extract``.
#
# Parameters
# ----------
# config: str
#     Full path of the config.yaml file.
#
# ...

# %%
rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',
                          threshold=0.5, 
                          window=30,
                          distance_threshold=1000,
                          forearm_wrist_low=0, forearm_wrist_up=1000, 
                          wrist_mcp_low=0, wrist_mcp_up=1000, 
                          mcp_pip_low=0, mcp_pip_up=1000,
                          pip_dip_low=0, pip_dip_up=1000,
                          distance=5,prominence=8)
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv
# Forearm wrist low: 0

# %%
rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',
                          threshold=0.5, 
                          window=30,
                          distance_threshold=1000,
                          forearm_wrist_low=0, forearm_wrist_up=1000, 
                          wrist_mcp_low=0, wrist_mcp_up=1000, 
                          mcp_pip_low=0, mcp_pip_up=1000,
                          pip_dip_low=0, pip_dip_up=1000,
                          distance=5,prominence=8)
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_200_filtered.csv
# Forearm wrist low: 0

# %%
rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_180_filtered.csv',
                          threshold=0.5, 
                          window=30,
                          distance_threshold=1000,
                          forearm_wrist_low=0, forearm_wrist_up=1000, 
                          wrist_mcp_low=0, wrist_mcp_up=1000, 
                          mcp_pip_low=0, mcp_pip_up=1000,
                          pip_dip_low=0, pip_dip_up=1000,
                          distance=5,prominence=8)
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_180_filtered.csv
# Forearm wrist low: 0

# %%
rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',
                          threshold=0, 
                          window=30,
                          distance_threshold=1000,
                          forearm_wrist_low=0, forearm_wrist_up=1000, 
                          wrist_mcp_low=0, wrist_mcp_up=1000, 
                          mcp_pip_low=0, mcp_pip_up=1000,
                          pip_dip_low=0, pip_dip_up=1000,
                          distance=5,prominence=8)

# %%
# TODO: Change the path to the CSV file, use a config file to store the path

rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_200_filtered.csv',threshold=0.5, window=30,distance_threshold=100,
                          forearm_wrist_low=400, forearm_wrist_up=600, wrist_mcp_low=400, wrist_mcp_up=550, mcp_pip_low=0, mcp_pip_up=1000,
                         pip_dip_low=0, pip_dip_up=1000,distance=5,prominence=8)
rhodes2 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',threshold=0.5, window=30,distance_threshold=200,
                          forearm_wrist_low=400, forearm_wrist_up=600, wrist_mcp_low=400, wrist_mcp_up=550, mcp_pip_low=0, mcp_pip_up=1000,
                         pip_dip_low=0, pip_dip_up=1000,distance=5,prominence=8)
rhodes1.plotDist()
rhodes1.plotJointDistances()


#rhodes.fitExponentialDecay(guess, removeStartSlice=6) #Not including the first 6 stims in the fit due to "Warming Up" period

guess = [2,2,160]
rhodes2.fitExponentialDecay(guess, removeStartSlice=6) #Not including the first 6 stims in the fit due to "Warming Up" period
#rhodes1.fitExponentialDecay(guess)
plotDecaySingle(rhodes2)
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_200_filtered.csv
# Forearm wrist low: 400
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv
# Forearm wrist low: 400

# %%
#rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_200_filtered.csv',threshold=0.5, window=30,distance_threshold=100,
                          #forearm_wrist_low=400, forearm_wrist_up=600, wrist_mcp_low=400, wrist_mcp_up=550, mcp_pip_low=0, mcp_pip_up=1000,
                         #pip_dip_low=0, pip_dip_up=1000,distance=5,prominence=8)
rhodes1 = FatigueAnalysis('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',threshold=0.5, window=30,distance_threshold=200,
                          forearm_wrist_low=400, forearm_wrist_up=600, wrist_mcp_low=400, wrist_mcp_up=550, mcp_pip_low=0, mcp_pip_up=1000,
                         pip_dip_low=0, pip_dip_up=1000,distance=5,prominence=8)
rhodes1.plotDist()
rhodes1.plotJointDistances()
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv
# Forearm wrist low: 400

# %%
guess = [2,2,160]
rhodes2.fitExponentialDecay(guess, removeStartSlice=6) #Not including the first 6 stims in the fit due to "Warming Up" period 
plotDecaySingle(rhodes2, remove_initial=4)

# %%
DataLoader('Monkey R','/home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv',threshold=0.5, window=30,distance_threshold=0,
                          forearm_wrist_low=50, forearm_wrist_up=100, wrist_mcp_low=100, wrist_mcp_up=250, mcp_pip_low=400, mcp_pip_up=500,
                         pip_dip_low=450, pip_dip_up=600)
# Out:
# Extracted data from /home/lucyliuu/Desktop/test-lucy-2024-11-05/videos/testDLC_Resnet50_testNov5shuffle1_snapshot_190_filtered.csv

# %%
x = 4000
a=(x/30)//60
b=(x/30)%60

print(a)
print(b)
# Out:
# 2.0
# 13.333333333333343
